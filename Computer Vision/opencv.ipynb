# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
img=cv2.imread(r"C:\Users\mishr\Pictures\Nitro\2024_Nitro_option_01_3840x2400.jpg")
img
# Out:
# array([[[ 36,  24,  24],
#         [ 36,  24,  24],
#         [ 36,  24,  24],
#         ...,
#         [ 34, 180, 255],
#         [ 35, 181, 255],
#         [ 35, 181, 255]],
#
#        [[ 21,   9,   9],
#         [ 21,   9,   9],
#         [ 21,   9,   9],
#         ...,
#         [ 31, 177, 253],
#         [ 31, 177, 253],
#         [ 31, 177, 253]],
#
#        [[ 18,   6,   6],
#         [ 18,   6,   6],
#         [ 18,   6,   6],
#         ...,
#         [ 26, 174, 252],
#         [ 26, 174, 252],
#         [ 26, 174, 252]],
#
#        ...,
#
#        [[  5,   0,   0],
#         [  5,   0,   0],
#         [  5,   0,   0],
#         ...,
#         [ 18,   6,   6],
#         [ 18,   6,   6],
#         [ 18,   6,   6]],
#
#        [[  9,   3,   4],
#         [  9,   3,   4],
#         [  9,   3,   4],
#         ...,
#         [ 21,   9,   9],
#         [ 21,   9,   9],
#         [ 21,   9,   9]],
#
#        [[ 24,  18,  19],
#         [ 24,  18,  19],
#         [ 24,  18,  19],
#         ...,
#         [ 36,  24,  24],
#         [ 36,  24,  24],
#         [ 36,  24,  24]]], shape=(2400, 3840, 3), dtype=uint8)

# %%
img.shape
# Out:
# (2400, 3840, 3)

# %%
cv2.imshow("Nitro",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(img[::,::,::-1])
plt.show()

# %%
a=np.random.randint(0,255,(5,5))
a
# Out:
# array([[ 10, 248,  60, 199,  86],
#        [200,   0,  13,  39, 163],
#        [227, 208,  69,  57,  90],
#        [ 16,  12, 235,  69, 248],
#        [120, 152, 224, 185,  97]], dtype=int32)

# %%
plt.imshow(a)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),0)
g=np.full((50,50),0)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),255)
g=np.full((50,50),255)
b=np.full((50,50),255)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),255)
g=np.full((50,50),0)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),0)
g=np.full((50,50),255)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),0)
g=np.full((50,50),0)
b=np.full((50,50),255)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),51)
g=np.full((50,50),255)
b=np.full((50,50),102)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
img=cv2.imread(r"C:\Users\mishr\Downloads\Ashok Chakra.jpeg")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], shape=(707, 2560, 3), dtype=uint8)

# %%
r=np.full((707,2560),255)
g=np.full((707,2560),120)
b=np.full((707,2560),10)



r=np.full((707,2560),255)
g=np.full((707,2560),255)
b=np.full((707,2560),255)


r=np.full((707,2560),20)
g=np.full((707,2560),255)
b=np.full((707,2560),100)



ac=img[::,::,::-1]

v=np.vstack((rgb,ac,rgb2))
plt.imshow(v)
plt.axis("off")
plt.show()

# %%
plt.imshow(img[::25,::25,::-1])
plt.show()

# %%
plt.imshow(a,cmap='grey')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=np.random.randint(0,255,(100,100))
a
# Out:
# array([[162, 128,  72, ..., 252,  65,  48],
#        [  1, 179, 203, ..., 146,  73, 213],
#        [254, 202, 207, ..., 148, 244,  82],
#        ...,
#        [137, 214, 230, ...,  71, 110,  32],
#        [113, 118, 144, ...,  18,  66, 196],
#        [ 37, 146, 169, ..., 175, 180,  51]], shape=(100, 100), dtype=int32)

# %%
plt.imshow(a)
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(ac, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(gray,cmap='gray')
plt.axis('off')
plt.show()

# %%
blur=cv2.GaussianBlur(ac,(113,115),5)
plt.imshow(blur)
plt.axis('off')
plt.show()
