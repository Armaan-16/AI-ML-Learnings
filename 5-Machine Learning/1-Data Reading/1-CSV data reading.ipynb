# %%
import pandas as pd
import numpy as np

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("msaimcodes/aug-train-csv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 288k/288k [00:00<00:00, 323kB/s]
# Extracting files...
# Path to dataset files: C:\Users\mishr\.cache\kagglehub\datasets\msaimcodes\aug-train-csv\versions\1

# %% [markdown]
# Read data from download

# %%
df = pd.read_csv(
    r'C:\Users\mishr\.cache\kagglehub\datasets\msaimcodes\aug-train-csv\versions\1\aug_train.csv',index_col='enrollee_id')
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# Read data from link

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
url = "https://raw.githubusercontent.com/ddavignon/CST-495/master/data/MovieSummaries/movie.metadata.tsv"
df = pd.read_csv(url, sep='\t',header=None)
df
# Out:
#               0           1  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
# ...         ...         ...
# 81736  35228177  /m/0j7hxnt
# 81737  34980460  /m/0g4pl34
# 81738   9971909  /m/02pygw1
# 81739    913762   /m/03pcrp
# 81740  12476867  /m/02w7zz8
#
#                                                        2           3  \
# 0                                         Ghosts of Mars  2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16
# 2                                            Brun bitter        1988
# 3                                       White Of The Eye        1987
# 4                                      A Woman in Flames        1983
# ...                                                  ...         ...
# 81736                           Mermaids: The Body Found  2011-03-19
# ...

# %%
columns = [
    "movie_id",
    "freebase_id",
    "movie_name",
    "release_date",
    "revenue",
    "runtime",
    "languages",
    "countries",
    "genres"
]

df = pd.read_csv(url, sep='\t', header=None, names=columns)
df
# Out:
#        movie_id freebase_id  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
# ...         ...         ...
# 81736  35228177  /m/0j7hxnt
# 81737  34980460  /m/0g4pl34
# 81738   9971909  /m/02pygw1
# 81739    913762   /m/03pcrp
# 81740  12476867  /m/02w7zz8
#
#                                               movie_name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# ...

# %%
path = kagglehub.dataset_download("diyanandy/testcsv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 25.2M/25.2M [00:06<00:00, 3.78MB/s]
# Extracting files...
# Path to dataset files: C:\Users\mishr\.cache\kagglehub\datasets\diyanandy\testcsv\versions\1

# %%
tst = pd.read_csv(
    r"C:\Users\mishr\.cache\kagglehub\datasets\diyanandy\testcsv\versions\1\test.csv"
,header=1)

tst
# Out:
#              0  B B.1 B.2  C B.3 B.4  A  E E.1  ... 0.4767390451101133  \
# 0            5  A   B   A  C   B   C  A  E   C  ...           0.285509
# 1           15  B   A   A  A   B   B  A  E   D  ...           0.697272
# 2           16  B   B   A  C   B   D  A  E   A  ...           0.719306
# 3           17  B   B   A  C   B   C  A  E   C  ...           0.313032
# 4           19  B   B   B  C   B   B  A  E   E  ...           0.489711
# ...        ... ..  ..  .. ..  ..  .. .. ..  ..  ...                ...
# 199994  499987  B   A   A  C   B   D  A  E   E  ...           0.287454
# 199995  499990  B   A   A  C   B   B  A  E   C  ...           0.794881
# 199996  499991  A   B   B  C   B   B  A  E   C  ...           0.514487
# 199997  499994  A   A   A  C   B   D  A  D   A  ...           0.286144
# 199998  499995  A   A   A  C   B   D  A  E   A  ...           0.286755
#
#         0.37634964704960105  0.3378838967546349  0.3218317548420124  \
# ...

# %% [markdown]
# To filter the required data columns

# %%
df = pd.read_csv(
    r"C:\Users\mishr\.cache\kagglehub\datasets\msaimcodes\aug-train-csv\versions\1\aug_train.csv",
    usecols=['enrollee_id', 'gender', 'education_level']
)

df.head()
# Out:
#    enrollee_id gender education_level
# 0         8949   Male        Graduate
# 1        29725   Male        Graduate
# 2        11561    NaN        Graduate
# 3        33241    NaN        Graduate
# 4          666   Male         Masters

# %%
path = kagglehub.dataset_download("rajeshrampure/zomato-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 89.0M/89.0M [00:07<00:00, 12.5MB/s]
# Extracting files...
# Path to dataset files: C:\Users\mishr\.cache\kagglehub\datasets\rajeshrampure\zomato-dataset\versions\1

# %%
zm = pd.read_csv(
    r"C:\Users\mishr\.cache\kagglehub\datasets\rajeshrampure\zomato-dataset\versions\1\zomato.csv"
)
zm
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...
