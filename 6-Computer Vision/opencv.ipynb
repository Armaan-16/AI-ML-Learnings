# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
img=cv2.imread(r"C:\Users\mishr\Pictures\Nitro\2024_Nitro_option_01_3840x2400.jpg") #OpenCV function used to read/load an image from a specified file path.
img # img = cv2.imread(path, flag)
# Out:
# array([[[ 36,  24,  24],
#         [ 36,  24,  24],
#         [ 36,  24,  24],
#         ...,
#         [ 34, 180, 255],
#         [ 35, 181, 255],
#         [ 35, 181, 255]],
#
#        [[ 21,   9,   9],
#         [ 21,   9,   9],
#         [ 21,   9,   9],
#         ...,
#         [ 31, 177, 253],
#         [ 31, 177, 253],
#         [ 31, 177, 253]],
#
#        [[ 18,   6,   6],
#         [ 18,   6,   6],
#         [ 18,   6,   6],
#         ...,
#         [ 26, 174, 252],
#         [ 26, 174, 252],
#         [ 26, 174, 252]],
#
#        ...,
#
#        [[  5,   0,   0],
#         [  5,   0,   0],
#         [  5,   0,   0],
#         ...,
#         [ 18,   6,   6],
#         [ 18,   6,   6],
#         [ 18,   6,   6]],
#
#        [[  9,   3,   4],
#         [  9,   3,   4],
#         [  9,   3,   4],
#         ...,
#         [ 21,   9,   9],
#         [ 21,   9,   9],
#         [ 21,   9,   9]],
#
#        [[ 24,  18,  19],
#         [ 24,  18,  19],
#         [ 24,  18,  19],
# ...

# %%
img.shape
# Returns the dimensions (shape) of the image array
           # Output format: (Height, Width, Channels)
           # Height  -> Number of rows (pixels vertically)
           # Width   -> Number of columns (pixels horizontally)
           # Channels-> Number of color channels
# Out:
# (2400, 3840, 3)

# %%
cv2.imshow("Nitro",img)
cv2.waitKey(0)  # Waits indefinitely until any key is pressedl
cv2.destroyAllWindows() # Closes all OpenCV windows that were opened

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(img[::,::,::-1])
plt.show()

# %%
a=np.random.randint(0,255,(5,5)) # np.random.randint(low, high, size)
a
# Out:
# array([[169,  60, 166, 146, 171],
#        [175, 226, 137, 212, 233],
#        [131, 199,  50, 229, 181],
#        [  5,  43,  80, 112, 201],
#        [  5,  87, 157, 191,  22]], dtype=int32)

# %%
plt.imshow(a)
plt.axis("off") # Hides the x-axis and y-axis ticks and labels.
plt.show()

# %%
r=np.full((50,50),0)# Creates an array of a specified shape filled with a given value.
g=np.full((50,50),0)#((row,col)intensity)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b)) # Stacks the three channels depth-wise to create an RGB image.
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),255)
g=np.full((50,50),255)
b=np.full((50,50),255)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),255)
g=np.full((50,50),0)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),0)
g=np.full((50,50),255)
b=np.full((50,50),0)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),0)
g=np.full((50,50),0)
b=np.full((50,50),255)

rgb=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
r=np.full((50,50),51)
g=np.full((50,50),255)
b=np.full((50,50),102)

rgb2=np.dstack((r,g,b))
plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
img=cv2.imread(r"C:\Users\mishr\Downloads\Ashok Chakra.jpeg")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Saffron stripe
r = np.full((707,2560),255,dtype=np.uint8)
g = np.full((707,2560),153,dtype=np.uint8)
b = np.full((707,2560),51,dtype=np.uint8)
rgb = np.dstack((r,g,b))

# Green stripe
r = np.full((707,2560),19,dtype=np.uint8)
g = np.full((707,2560),136,dtype=np.uint8)
b = np.full((707,2560),8,dtype=np.uint8)
rgb2 = np.dstack((r,g,b))

# Ashoka Chakra image
ac = img[:,:,::-1]   # Convert BGR to RGB

# Combine stripes and chakra
v = np.vstack((rgb, ac, rgb2))

plt.imshow(v)
plt.axis("off")
plt.show()

# %%
plt.imshow(img[::25,::25,::-1])
plt.show()
# First ::25
# Selects every 25th row.
# Reduces the image height.

# Second ::25
# Selects every 25th column.
# Reduces the image width.

# Third ::-1
# Reverses the color channels.
# Converts BGR → RGB when image is loaded using OpenCV.

# Shape change example:
# Original: (1080, 1920, 3)
# New:      (44, 77, 3)

# This operation is called image downsampling.
# It reduces image size by keeping every 25th pixel.

# %%
plt.imshow(a,cmap='grey')
plt.axis('off')
plt.show
# cmap='gray':
# Uses the grayscale colormap.
# 0   = Black
# 255 = White
# Values between 0 and 255 appear as different shades of gray.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=np.random.randint(0,255,(100,100))
a
# Out:
# array([[ 60, 237, 195, ...,   3, 253,  38],
#        [ 52, 254,   1, ..., 140, 207,   7],
#        [ 48,  61, 245, ..., 146, 172, 222],
#        ...,
#        [ 10,  80, 200, ...,  62, 239,  34],
#        [162,  13, 199, ...,  54,  81, 220],
#        [ 70, 249,  31, ..., 172, 175, 170]], shape=(100, 100), dtype=int32)

# %%
plt.imshow(a)
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(ac, cv2.COLOR_BGR2GRAY) # Converts an image from one color space to another.
cv2.imshow("Gray", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(gray,cmap='gray')
plt.axis('off')
plt.show()

# %%
blur=cv2.GaussianBlur(ac,(1,113),10)
plt.imshow(blur)
plt.axis('off')
plt.show()

# %%
edge=cv2.Canny(ac,100,200)
plt.imshow(edge,cmap='gray')
plt.axis('off')
plt.show()

# %%
cap=cv2.VideoCapture(0)
if cap.isOpened():
    ret,frame=cap.read()
    print(ret)
    print(frame)
else:
    ret=False
Image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
plt.imshow(Image)
plt.title("Webcam")
plt.xticks([])
plt.yticks([])
plt.show()
cap.release()
# Out:
# True
# [[[120 127 112]
#   [119 128 109]
#   [117 129 103]
#   ...
#   [222 203 213]
#   [223 205 215]
#   [224 207 217]]
#
#  [[120 127 113]
#   [119 127 110]
#   [117 128 105]
#   ...
#   [222 204 213]
#   [221 205 213]
#   [220 204 212]]
#
#  [[120 126 112]
#   [119 127 111]
#   [117 127 107]
#   ...
#   [219 205 211]
#   [219 205 210]
#   [219 205 210]]
#
#  ...
#
#  [[ 71  77  83]
#   [ 70  76  82]
#   [ 69  75  81]
#   ...
#   [153 156 167]
#   [153 156 167]
#   [157 160 171]]
#
#  [[ 75  80  86]
#   [ 75  80  85]
#   [ 74  79  84]
#   ...
#   [147 147 160]
#   [153 154 165]
#   [152 153 164]]
#
#  [[ 78  82  87]
#   [ 78  82  87]
#   [ 77  81  86]
#   ...
#   [136 135 148]
#   [164 163 176]
#   [157 157 168]]]

# %%
vdo=r"C:\Users\mishr\Videos\FAMILY TRIPS\CHILIKA\MVI_6218.MP4"
cv2.namedWindow(vdo)
cap=cv2.VideoCapture(vdo)
if cap.isOpened():
    ret,frame=cap.read()
    print(ret)
    print(frame)
else:
    ret=False
while ret:
    ret,frame =cap.read()
    if not ret:
        break
    cv2.imshow(vdo,frame)
    if cv2.imshow(vdo,frame):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# True
# [[[ 53  54  50]
#   [ 55  56  52]
#   [ 58  59  55]
#   ...
#   [223 214 214]
#   [223 214 214]
#   [223 214 214]]
#
#  [[ 55  56  52]
#   [ 56  57  53]
#   [ 56  57  53]
#   ...
#   [223 214 214]
#   [223 214 214]
#   [223 214 214]]
#
#  [[ 58  59  55]
#   [ 56  57  53]
#   [ 56  57  53]
#   ...
#   [223 214 214]
#   [223 214 214]
#   [223 214 214]]
#
#  ...
#
#  [[ 53  56  52]
#   [ 53  56  52]
#   [ 53  56  52]
#   ...
#   [225 216 216]
#   [225 216 216]
#   [225 216 216]]
#
#  [[ 53  56  52]
#   [ 53  56  52]
#   [ 53  56  52]
#   ...
#   [225 216 216]
#   [225 216 216]
#   [225 216 216]]
#
#  [[ 54  57  53]
#   [ 54  57  53]
#   [ 53  56  52]
#   ...
#   [225 216 216]
#   [225 216 216]
#   [225 216 216]]]
